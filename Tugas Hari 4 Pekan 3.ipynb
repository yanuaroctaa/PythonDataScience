# %% [markdown]
# Downoad  <a href="https://blog.sanbercode.com/wp-content/uploads/2020/05/vgsales.csv">vgsales.csv</a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# <h2>Soal 1: Preparing Data</h2>
#
# Manipulasi data tersebut dengan menggroupkan berdasarkan Genre, kemudian ambil rata2 penjualan untuk setiap Region Kecuali Global_Sales berdasarkan kategori Genre.

# %%
#code here
df_mean=df.groupby("Genre")[["NA_Sales","EU_Sales","JP_Sales","Other_Sales"]].mean()
df_mean
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Action        0.264726  0.158323  0.048236     0.056508
# Adventure     0.082271  0.049868  0.040490     0.013072
# Fighting      0.263667  0.119481  0.103007     0.043255
# Misc          0.235906  0.124198  0.061967     0.043312
# Platform      0.504571  0.227573  0.147596     0.058228
# Puzzle        0.212680  0.087251  0.098471     0.021564
# Racing        0.287766  0.190865  0.045388     0.061865
# Role-Playing  0.219946  0.126384  0.236767     0.040060
# Shooter       0.444733  0.239137  0.029221     0.078389
# Simulation    0.211430  0.130773  0.073472     0.036355
# Sports        0.291283  0.160635  0.057702     0.057532
# Strategy      0.100881  0.066579  0.072628     0.016681

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1dR4vthSt22gM_LdfSBZCMIKPL6xd7nVl)

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 2: Perbandingan Kuantitatif Barplot - Grouping Visualisasi Dengan Barplot</h2>
#
# 1. Visualisasikan gambar yang tadi kita manipulasi, untuk menghasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %%
#code here
import numpy as np
plt.gcf().set_size_inches(15, 8)

plt.style.use("ggplot")
x = np.arange(0, 16, 4)
width = 0.3
y = df_mean["Action"]
y1 = df_mean['Adventure']
y2 = df_mean['Fighting']
y3 = df_mean['Misc']
y4 = df_mean['Platform']
y5 = df_mean['Puzzle']
y6 = df_mean['Racing']
y7 = df_mean['Role-Playing']
y8 = df_mean['Shooter']
y9 = df_mean['Simulation']
y10 = df_mean['Sports']
y11 = df_mean['Strategy']

ax.bar(x, y,width,label='Action')
ax.bar(x+0.3, y,width,label='Adventure')
ax.bar(x+0.6, y,width,label='Fighting')
ax.bar(x+0.9, y,width,label='Misc')
ax.bar(x+1.2, y,width,label='Platform')
ax.bar(x+1.5, y,width,label='Puzzle')
ax.bar(x+1.8, y,width,label='Racing')
ax.bar(x+2.1, y,width,label='Role-Playing')
ax.bar(x+2.4, y,width,label='Shooter')
ax.bar(x+2.7, y,width,label='Simulation')
ax.bar(x+3.0, y,width,label='Sports')
ax.bar(x+3.3, y,width,label='Strategy')

ax.set_xticks(x+1.5)
ax.set_xticklabels(df_mean.index)
ax.set_title("Mean Sales Video Games By Genre")
ax.set_xlabel("Region Sales")
ax.set_ylabel("Mean Sales")
ax.legends(bbox_to_anchor=(1.1,1.1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Action'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-cac5fb723094> in <module>
# ...

# %% [markdown]
# Jawab:
#
# dari rata rata pembelian game, terlihat bahwa pembelian game di dominasi oleh  genre Platform di NA sales, dan memang terlihat juga bahwa dari berbagai regional pun NA yang paling tinggi untuk pembelian gamenya

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1A2s9Uy2i471VEYIZqMoVUIlZnVOUc8ha)

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 3: Perbandingan Kuantitatif Barplot - Stack Barplot</h2>
#
# 1. Visualisasikan gambar yang tadi kita manipulasi, untuk menhasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %%
for i,j in enumerate(df_mean.columns):
    print(i,j)
# Out:
# 0 NA_Sales
# 1 EU_Sales
# 2 JP_Sales
# 3 Other_Sales

# %%
#code here
plt.gcf().set_size_inches(15, 8)

plt.style.use("ggplot")
x = np.arange(0, 16, 4)
width = 0.3

for i,j in enumerate(df_mean.columns):
    ax.bar(x+(i*width), df_mean[j],width,label=j)

ax.set_xticks(x+1.5)
ax.set_xticklabels(df_mean.index)
ax.set_title("Mean Sales Video Games By Genre")
ax.set_xlabel("Region Sales")
ax.set_ylabel("Mean Sales")
ax.legends(bbox_to_anchor=(1.1,1.1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-024ff2e8325a> in <module>
#       7
#       8 for i,j in enumerate(df_mean.columns):
# ----> 9     ax.bar(x+(i*width), df_mean[j],width,label=j)
#      10
#      11 ax.set_xticks(x+1.5)
#
# NameError: name 'ax' is not defined

# %% [markdown]
# Jawab:

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1_yis-3aZsEbsk68tpoPHoNlFftaz2GrO)
